# %%
import pandas as pd
import numpy as np

# %%
crime = pd.read_csv("NYPD_Complaint_Data_Historic.csv")
crime
# Out:
# /var/folders/l7/1vvcr1f15s9dpkc1xqbr10gc0000gn/T/ipykernel_77299/1366445726.py:1: DtypeWarning: Columns (18,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   crime = pd.read_csv("NYPD_Complaint_Data_Historic.csv")
#          CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 0         394506329   12/31/2019     17:30:00          NaN          NaN
# 1         968873685   12/29/2019     16:31:00   12/29/2019     16:54:00
# 2         509837549   12/15/2019     18:45:00          NaN          NaN
# 3         352454313   12/28/2019     01:00:00          NaN          NaN
# 4         248803469   09/05/2008     21:41:00          NaN          NaN
# ...             ...          ...          ...          ...          ...
# 7825494   744350707   12/17/2018     03:00:00   12/17/2018     03:05:00
# 7825495   380927470   06/05/2018     23:30:00   06/06/2018     11:00:00
# 7825496   502083804   02/10/2018     08:30:00   02/10/2018     08:45:00
# ...

# %%
crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7825499 entries, 0 to 7825498
# Data columns (total 35 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   CMPLNT_NUM         int64
#  1   CMPLNT_FR_DT       object
#  2   CMPLNT_FR_TM       object
#  3   CMPLNT_TO_DT       object
#  4   CMPLNT_TO_TM       object
#  5   ADDR_PCT_CD        float64
#  6   RPT_DT             object
#  7   KY_CD              int64
#  8   OFNS_DESC          object
#  9   PD_CD              float64
#  10  PD_DESC            object
#  11  CRM_ATPT_CPTD_CD   object
#  12  LAW_CAT_CD         object
#  13  BORO_NM            object
#  14  LOC_OF_OCCUR_DESC  object
#  15  PREM_TYP_DESC      object
#  16  JURIS_DESC         object
#  17  JURISDICTION_CODE  float64
#  18  PARKS_NM           object
#  19  HADEVELOPT         object
#  20  HOUSING_PSA        object
#  21  X_COORD_CD         float64
#  22  Y_COORD_CD         float64
#  23  SUSP_AGE_GROUP     object
# ...

# %%
crime_renamed = crime.rename(columns = {
'CMPLNT_NUM': 'id',#
'CMPLNT_FR_DT': 'start_date_of_event',#
'CMPLNT_FR_TM': 'start_time_of_event',#
'CMPLNT_TO_DT': 'end_date_of_event',
'CMPLNT_TO_TM': 'end_time_of_event',
'ADDR_PCT_CD': 'precinct',
'RPT_DT': 'date_police_report',#
'KY_CD': 'offense_class',
'OFNS_DESC': 'description',#
'PD_CD': 'offense_key',
'PD_DESC': 'police_description',
'CRM_ATPT_CPTD_CD': 'crime_completion',
'LAW_CAT_CD': 'offense_level',
'BORO_NM': 'boro',#
'LOC_OF_OCCUR_DESC': 'spatial_loc',
'PREM_TYP_DESC': 'location_type',
'JURIS_DESC': 'juris_description',
'JURISDICTION_CODE': 'juris_code',
'PARKS_NM': 'greenspace_name',
'HADEVELOPT': 'NYCHA_name',
'HOUSING_PSA': 'dvlpmnt_lvl_code',
'X_COORD_CD': 'X_coord',
'Y_COORD_CD': 'y_coord',
'SUSP_AGE_GROUP': 'suspect_age',
'SUSP_RACE': 'suspect_race',
'SUSP_SEX': 'suspect_sex',
'TRANSIT_DISTRICT': 'trans_dstrct',
'Latitude': 'lat',#
'Longitude': 'lon',#
'Lat_Lon': 'lat_lon',
'PATROL_BORO': 'patrol_boro',
'STATION_NAME': 'trans_station_name',
'VIC_AGE_GROUP': 'victim_age',
'VIC_RACE': 'victim_race',
'VIC_SEX': 'victim_sex'
}).copy()

# %%
crime_renamed.to_csv("NYPD_Complaint_Renamed.csv", index = False)

# %%
crime_reduced = crime_renamed[[
    'id',
    'start_date_of_event',
    'start_time_of_event',
    'precinct',
    'date_police_report',
    'description',
    'police_description',
    'offense_level',
    'boro',
    'location_type',
    'juris_description',
    'lat',
    'lon',
    'trans_station_name',
    'victim_age',
    'victim_race',
    'victim_sex'
]]

# %%
crime_reduced.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7825499 entries, 0 to 7825498
# Data columns (total 17 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   id                   int64
#  1   start_date_of_event  object
#  2   start_time_of_event  object
#  3   precinct             float64
#  4   date_police_report   object
#  5   description          object
#  6   police_description   object
#  7   offense_level        object
#  8   boro                 object
#  9   location_type        object
#  10  juris_description    object
#  11  lat                  float64
#  12  lon                  float64
#  13  trans_station_name   object
#  14  victim_age           object
#  15  victim_race          object
#  16  victim_sex           object
# dtypes: float64(3), int64(1), object(13)
# memory usage: 1015.0+ MB

# %%
crime_reduced.head()
# Out:
#           id start_date_of_event start_time_of_event  precinct  \
# 0  394506329          12/31/2019            17:30:00      32.0
# 1  968873685          12/29/2019            16:31:00      47.0
# 2  509837549          12/15/2019            18:45:00     109.0
# 3  352454313          12/28/2019            01:00:00      47.0
# 4  248803469          09/05/2008            21:41:00       NaN
#
#   date_police_report                      description  \
# 0         12/31/2019                DANGEROUS WEAPONS
# 1         12/29/2019                          FORGERY
# 2         12/29/2019                    HARRASSMENT 2
# 3         12/28/2019          MISCELLANEOUS PENAL LAW
# 4         09/05/2008  MURDER & NON-NEGL. MANSLAUGHTER
#
#                police_description offense_level       boro location_type  \
# 0            WEAPONS POSSESSION 3        FELONY  MANHATTAN        STREET
# 1  FORGERY,ETC.,UNCLASSIFIED-FELO        FELONY      BRONX        STREET
# ...

# %%
crime_reduced.to_csv("NYPD_Complaint.csv", index = False)
